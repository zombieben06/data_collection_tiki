# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# NỒI CƠM ĐIỆN

# %%
import requests
import time
import random
import pandas as pd

# cookies = {
#     'TIKI_GUEST_TOKEN': '8jWSuIDBb2NGVzr6hsUZXpkP1FRin7lY',
#     'TOKENS': '{%22access_token%22:%228jWSuIDBb2NGVzr6hsUZXpkP1FRin7lY%22%2C%22expires_in%22:157680000%2C%22expires_at%22:1763654224277%2C%22guest_token%22:%228jWSuIDBb2NGVzr6hsUZXpkP1FRin7lY%22}',
#     'amp_99d374': 'eSc-_0HT1um7cb57E7dwA0...1enloc6a2.1enlpc1q6.b.i.t',
#     'amp_99d374_tiki.vn': 'eSc-_0HT1um7cb57E7dwA0...1enloc6a2.1enlp8817.3.1.1',
#     '_gcl_au': '1.1.559117409.1605974236',
#     '_ants_utm_v2': '',
#     '_pk_id.638735871.2fc5': 'b92ae025fbbdb31f.1605974236.1.1605975278.1605974236.',
#     '_pk_ses.638735871.2fc5': '*',
#     '_trackity': '70e316b0-96f2-dbe1-a2ed-43ff60419991',
#     '_ga_NKX31X43RV': 'GS1.1.1605974235.1.1.1605975326.0',
#     '_ga': 'GA1.1.657946765.1605974236',
#     'ai_client_id': '11935756853.1605974227',
#     'an_session': 'zizkzrzjzlzizqzlzqzjzdzizizqzgzmzkzmzlzrzmzgzdzizlzjzmzqzkznzhzhzkzdzizhzdzizlzjzmzqzkznzhzhzkzdzizlzjzmzqzkznzhzhzkzdzjzdzhzqzdzizd2f27zdzjzdzlzmzmznzq',
#     'au_aid': '11935756853',
#     'dgs': '1605975268%3A3%3A0',
#     'au_gt': '1605974227146',
#     '_ants_services': '%5B%22cuid%22%5D',
#     '__admUTMtime': '1605974236',
#     '__iid': '749',
#     '__su': '0',
#     '_bs': 'bb9a32f6-ab13-ce80-92d6-57fd3fd6e4c8',
#     '_gid': 'GA1.2.867846791.1605974237',
#     '_fbp': 'fb.1.1605974237134.1297408816',
#     '_hjid': 'f152cf33-7323-4410-b9ae-79f6622ebc48',
#     '_hjFirstSeen': '1',
#     '_hjIncludedInPageviewSample': '1',
#     '_hjAbsoluteSessionInProgress': '0',
#     '_hjIncludedInSessionSample': '1',
#     'tiki_client_id': '657946765.1605974236',
#     '__gads': 'ID=ae56424189ecccbe-227eb8e1d6c400a8:T=1605974229:RT=1605974229:S=ALNI_MZFWYf2BAjzCSiRNLC3bKI-W_7YHA',
#     'proxy_s_sv': '1605976041662',
#     'TKSESSID': '8bcd49b02e1e16aa1cdb795c54d7b460',
#     'TIKI_RECOMMENDATION': '21dd50e7f7c194df673ea3b717459249',
#     'cto_bundle': 'V9Dkml9NVXNkQmJ6aEVLcXNqbHdjcVZoQ0l5RXpOMlRybjdDT0JrUnNxVXc2bHd0N2J3Y2FCdmZVQXdYY1QlMkJYUmxXSHZ2UEFwd3IzRHhzRWJYMlQlMkJsQjhjQlA1JTJCcExyRzlUQk5CYUdMdjl2STNQanVsa3cycHd3SHElMkJabnI3dzNhREpZcFVyandyM1d1QWpJbWYxT1UyWDdHZyUzRCUzRA',
#     'TIKI_RECENTLYVIEWED': '58259141',
#     '_ants_event_his': '%7B%22action%22%3A%22view%22%2C%22time%22%3A1605974691247%7D',
#     '_gat': '1',
# }

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/search?q=n%E1%BB%93i%20c%C6%A1m%20%C4%91i%E1%BB%87n',
    'x-guest-token': 'io5g4hskF971zqMNtRm30QcIlV2vLuJf',
    'Connection': 'keep-alive',
    'TE': 'chunked',
}

params = {
    'limit': '40',
    'include': 'advertisement',
    'aggregations': '2',
    'trackity_id': 'd775c484-83cc-d67a-db5e-8f1e70299c40',
    'q': 'nồi cơm điện',
    '_v': 'reduce_ads_092025',
}

product_id = []
for i in range(1, 11):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)
    if response.status_code == 200:
        print('request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
    time.sleep(random.randrange(3, 10))

df = pd.DataFrame(product_id)
df.to_csv('/content/drive/MyDrive/Tiki_crawled_data/NỒI CƠM ĐIỆN/NOICOMDIEN_id_ncds.csv', index=False)
# Out:
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!

# %%
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import time
import random

# Cấu hình session với connection pooling và retry
def create_session():
    session = requests.Session()
    retry_strategy = Retry(
        total=3,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504],
    )
    adapter = HTTPAdapter(
        max_retries=retry_strategy,
        pool_connections=50,
        pool_maxsize=50
    )
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    return session

# Headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/',
    'Connection': 'keep-alive',
}

def parser_product(json_data):
    """Parse JSON response thành dictionary"""
    return {
        'id': json_data.get('id'),
        'name': json_data.get('name'),
        'short_description': json_data.get('short_description'),
        'price': json_data.get('price'),
        'discount': json_data.get('discount'),
        'discount_rate': json_data.get('discount_rate'),
        'review_count': json_data.get('review_count'),
        'day_ago_created': json_data.get('day_ago_created', {}) if isinstance(json_data.get('day_ago_created'), dict) else None,
        'quantity_sold': json_data.get('quantity_sold', {}).get('value') if isinstance(json_data.get('quantity_sold'), dict) else None,
        'brand_name': json_data.get('brand', {}).get('name') if isinstance(json_data.get('brand'), dict) else None
    }

def crawl_product(pid, session):
    """Crawl một sản phẩm"""
    try:
        url = f'https://tiki.vn/api/v2/products/{pid}'
        params = {
            'platform': 'web',
            'spid': pid,
            'version': 3
        }

        response = session.get(url, headers=headers, params=params, timeout=15)

        if response.status_code == 200:
            content_type = response.headers.get('Content-Type', '')

            if 'application/json' in content_type:
                json_data = response.json()
                return {'status': 'success', 'data': parser_product(json_data), 'id': pid}
            else:
                return {'status': 'error', 'reason': 'Not JSON response', 'id': pid}

        elif response.status_code == 404:
            return {'status': 'error', 'reason': '404 Not Found', 'id': pid}
        elif response.status_code == 403:
            return {'status': 'error', 'reason': '403 Forbidden', 'id': pid}
        else:
            return {'status': 'error', 'reason': f'HTTP {response.status_code}', 'id': pid}

    except requests.exceptions.Timeout:
        return {'status': 'error', 'reason': 'Timeout', 'id': pid}
    except requests.exceptions.JSONDecodeError:
        return {'status': 'error', 'reason': 'JSON decode error', 'id': pid}
    except Exception as e:
        return {'status': 'error', 'reason': str(e)[:100], 'id': pid}

def crawl_batch(p_ids, max_workers=10, delay_range=(0.1, 0.3)):
    """Crawl nhiều sản phẩm song song"""
    session = create_session()
    results = []
    failed_ids = []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit tất cả tasks
        future_to_pid = {
            executor.submit(crawl_product, pid, session): pid
            for pid in p_ids
        }

        # Progress bar
        with tqdm(total=len(p_ids), desc="Crawling") as pbar:
            for future in as_completed(future_to_pid):
                result = future.result()

                if result['status'] == 'success':
                    results.append(result['data'])
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})
                else:
                    failed_ids.append({'id': result['id'], 'reason': result['reason']})
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})

                pbar.update(1)

                # Delay nhỏ giữa các requests
                time.sleep(random.uniform(*delay_range))

    session.close()
    return results, failed_ids

# Main execution
if __name__ == "__main__":
    print("Đang đọc file product IDs...")
    df_id = pd.read_csv('/content/drive/MyDrive/Tiki_crawled_data/NỒI CƠM ĐIỆN/NOICOMDIEN_id_ncds.csv')
    p_ids = df_id.id.to_list()
    print(f"Tổng số sản phẩm: {len(p_ids)}")

    # Crawl với 10 workers song song
    print("\nBắt đầu crawl...")
    start_time = time.time()

    results, failed_ids = crawl_batch(
        p_ids,
        max_workers=10,  # Số luồng song song (tăng lên 15-20 nếu muốn nhanh hơn)
        delay_range=(0.1, 0.3)  # Delay ngắn giữa các requests
    )

    elapsed_time = time.time() - start_time

    # Lưu kết quả
    if results:
        df_product = pd.DataFrame(results)
        df_product.to_csv('/content/drive/MyDrive/Tiki_crawled_data/NỒI CƠM ĐIỆN/NOICOMDIEN_data_ncds.csv', index=False)
        print(f'\n✓ Đã lưu {len(results)} sản phẩm vào crawled_data_ncds.csv')

    if failed_ids:
        df_failed = pd.DataFrame(failed_ids)
        df_failed.to_csv('/content/drive/MyDrive/Tiki_crawled_data/NỒI CƠM ĐIỆN/NOICOMDIEN_failed_ids_ncds.csv', index=False)
        print(f'✗ Đã lưu {len(failed_ids)} ID thất bại vào failed_ids_ncds.csv')

    # Thống kê
    print(f'\n{"="*60}')
    print(f'Tổng thời gian: {elapsed_time:.2f}s ({elapsed_time/60:.2f} phút)')
    print(f'Tốc độ trung bình: {len(p_ids)/elapsed_time:.2f} sản phẩm/giây')
    print(f'Thành công: {len(results)} ({len(results)/len(p_ids)*100:.1f}%)')
    print(f'Thất bại: {len(failed_ids)} ({len(failed_ids)/len(p_ids)*100:.1f}%)')
    print(f'{"="*60}')
# Out:
# Đang đọc file product IDs...
# Tổng số sản phẩm: 378
#
# Bắt đầu crawl...
# Crawling:  62%|██████▏   | 234/378 [00:46<00:30,  4.78it/s, ✓=124, ✗=110]WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='maintenance.tiki.vn', port=443): Read timed out. (read timeout=15)")': /
# Crawling: 100%|██████████| 378/378 [01:16<00:00,  4.94it/s, ✓=157, ✗=221]
# ✓ Đã lưu 157 sản phẩm vào crawled_data_ncds.csv
# ✗ Đã lưu 221 ID thất bại vào failed_ids_ncds.csv
#
# ============================================================
# Tổng thời gian: 76.57s (1.28 phút)
# Tốc độ trung bình: 4.94 sản phẩm/giây
# Thành công: 157 (41.5%)
# Thất bại: 221 (58.5%)
# ============================================================

# %% [markdown]
# TỦ LẠNH

# %%
import requests
import time
import random
import pandas as pd

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/search?q=t%E1%BB%A7%20l%E1%BA%A1nh',
    'x-guest-token': 'io5g4hskF971zqMNtRm30QcIlV2vLuJf',
    'Connection': 'keep-alive',
    'TE': 'chunked',
}

params = {
    'limit': '40',
    'include': 'advertisement',
    'aggregations': '2',
    'trackity_id': 'd775c484-83cc-d67a-db5e-8f1e70299c40',
    'q': 'tủ lạnh',
    '_v': 'reduce_ads_092025',
}

product_id = []
for i in range(1, 11):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)
    if response.status_code == 200:
        print('request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
    time.sleep(random.randrange(3, 10))

df = pd.DataFrame(product_id)
df.to_csv('/content/drive/MyDrive/Tiki_crawled_data/TỦ LẠNH/TULANH_id_ncds.csv', index=False)
# Out:
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!

# %%
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import time
import random

# Cấu hình session với connection pooling và retry
def create_session():
    session = requests.Session()
    retry_strategy = Retry(
        total=3,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504],
    )
    adapter = HTTPAdapter(
        max_retries=retry_strategy,
        pool_connections=50,
        pool_maxsize=50
    )
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    return session

# Headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/',
    'Connection': 'keep-alive',
}

def parser_product(json_data):
    """Parse JSON response thành dictionary"""
    return {
        'id': json_data.get('id'),
        'name': json_data.get('name'),
        'short_description': json_data.get('short_description'),
        'price': json_data.get('price'),
        'discount': json_data.get('discount'),
        'discount_rate': json_data.get('discount_rate'),
        'review_count': json_data.get('review_count'),
        'day_ago_created': json_data.get('day_ago_created', {}) if isinstance(json_data.get('day_ago_created'), dict) else None,
        'quantity_sold': json_data.get('quantity_sold', {}).get('value') if isinstance(json_data.get('quantity_sold'), dict) else None,
        'brand_name': json_data.get('brand', {}).get('name') if isinstance(json_data.get('brand'), dict) else None
    }

def crawl_product(pid, session):
    """Crawl một sản phẩm"""
    try:
        url = f'https://tiki.vn/api/v2/products/{pid}'
        params = {
            'platform': 'web',
            'spid': pid,
            'version': 3
        }

        response = session.get(url, headers=headers, params=params, timeout=15)

        if response.status_code == 200:
            content_type = response.headers.get('Content-Type', '')

            if 'application/json' in content_type:
                json_data = response.json()
                return {'status': 'success', 'data': parser_product(json_data), 'id': pid}
            else:
                return {'status': 'error', 'reason': 'Not JSON response', 'id': pid}

        elif response.status_code == 404:
            return {'status': 'error', 'reason': '404 Not Found', 'id': pid}
        elif response.status_code == 403:
            return {'status': 'error', 'reason': '403 Forbidden', 'id': pid}
        else:
            return {'status': 'error', 'reason': f'HTTP {response.status_code}', 'id': pid}

    except requests.exceptions.Timeout:
        return {'status': 'error', 'reason': 'Timeout', 'id': pid}
    except requests.exceptions.JSONDecodeError:
        return {'status': 'error', 'reason': 'JSON decode error', 'id': pid}
    except Exception as e:
        return {'status': 'error', 'reason': str(e)[:100], 'id': pid}

def crawl_batch(p_ids, max_workers=10, delay_range=(0.1, 0.3)):
    """Crawl nhiều sản phẩm song song"""
    session = create_session()
    results = []
    failed_ids = []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit tất cả tasks
        future_to_pid = {
            executor.submit(crawl_product, pid, session): pid
            for pid in p_ids
        }

        # Progress bar
        with tqdm(total=len(p_ids), desc="Crawling") as pbar:
            for future in as_completed(future_to_pid):
                result = future.result()

                if result['status'] == 'success':
                    results.append(result['data'])
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})
                else:
                    failed_ids.append({'id': result['id'], 'reason': result['reason']})
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})

                pbar.update(1)

                # Delay nhỏ giữa các requests
                time.sleep(random.uniform(*delay_range))

    session.close()
    return results, failed_ids

# Main execution
if __name__ == "__main__":
    print("Đang đọc file product IDs...")
    df_id = pd.read_csv('/content/drive/MyDrive/Tiki_crawled_data/TỦ LẠNH/TULANH_id_ncds.csv')
    p_ids = df_id.id.to_list()
    print(f"Tổng số sản phẩm: {len(p_ids)}")

    # Crawl với 10 workers song song
    print("\nBắt đầu crawl...")
    start_time = time.time()

    results, failed_ids = crawl_batch(
        p_ids,
        max_workers=10,  # Số luồng song song (tăng lên 15-20 nếu muốn nhanh hơn)
        delay_range=(0.1, 0.3)  # Delay ngắn giữa các requests
    )

    elapsed_time = time.time() - start_time

    # Lưu kết quả
    if results:
        df_product = pd.DataFrame(results)
        df_product.to_csv('/content/drive/MyDrive/Tiki_crawled_data/TỦ LẠNH/TULANH_data_ncds.csv', index=False)
        print(f'\n✓ Đã lưu {len(results)} sản phẩm vào crawled_data_ncds.csv')

    if failed_ids:
        df_failed = pd.DataFrame(failed_ids)
        df_failed.to_csv('/content/drive/MyDrive/Tiki_crawled_data/TỦ LẠNH/TULANH_failed_ids_ncds.csv', index=False)
        print(f'✗ Đã lưu {len(failed_ids)} ID thất bại vào failed_ids_ncds.csv')

    # Thống kê
    print(f'\n{"="*60}')
    print(f'Tổng thời gian: {elapsed_time:.2f}s ({elapsed_time/60:.2f} phút)')
    print(f'Tốc độ trung bình: {len(p_ids)/elapsed_time:.2f} sản phẩm/giây')
    print(f'Thành công: {len(results)} ({len(results)/len(p_ids)*100:.1f}%)')
    print(f'Thất bại: {len(failed_ids)} ({len(failed_ids)/len(p_ids)*100:.1f}%)')
    print(f'{"="*60}')
# Out:
# Đang đọc file product IDs...
# Tổng số sản phẩm: 400
#
# Bắt đầu crawl...
# Crawling: 100%|██████████| 400/400 [01:21<00:00,  4.89it/s, ✓=191, ✗=209]
# ✓ Đã lưu 191 sản phẩm vào crawled_data_ncds.csv
# ✗ Đã lưu 209 ID thất bại vào failed_ids_ncds.csv
#
# ============================================================
# Tổng thời gian: 81.88s (1.36 phút)
# Tốc độ trung bình: 4.89 sản phẩm/giây
# Thành công: 191 (47.8%)
# Thất bại: 209 (52.2%)
# ============================================================

# %% [markdown]
# BẾP

# %%
import requests
import time
import random
import pandas as pd

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/search?q=b%E1%BA%BFp',
    'x-guest-token': 'io5g4hskF971zqMNtRm30QcIlV2vLuJf',
    'Connection': 'keep-alive',
    'TE': 'chunked',
}

params = {
    'limit': '40',
    'include': 'advertisement',
    'aggregations': '2',
    'trackity_id': 'd775c484-83cc-d67a-db5e-8f1e70299c40',
    'q': 'bếp',
    '_v': 'reduce_ads_092025',
}

product_id = []
for i in range(1, 11):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)
    if response.status_code == 200:
        print('request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
    time.sleep(random.randrange(3, 10))

df = pd.DataFrame(product_id)
df.to_csv('/content/drive/MyDrive/Tiki_crawled_data/BẾP/BEP_id_ncds.csv', index=False)
# Out:
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!

# %%
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import time
import random

# Cấu hình session với connection pooling và retry
def create_session():
    session = requests.Session()
    retry_strategy = Retry(
        total=3,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504],
    )
    adapter = HTTPAdapter(
        max_retries=retry_strategy,
        pool_connections=50,
        pool_maxsize=50
    )
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    return session

# Headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/',
    'Connection': 'keep-alive',
}

def parser_product(json_data):
    """Parse JSON response thành dictionary"""
    return {
        'id': json_data.get('id'),
        'name': json_data.get('name'),
        'short_description': json_data.get('short_description'),
        'price': json_data.get('price'),
        'discount': json_data.get('discount'),
        'discount_rate': json_data.get('discount_rate'),
        'review_count': json_data.get('review_count'),
        'day_ago_created': json_data.get('day_ago_created', {}) if isinstance(json_data.get('day_ago_created'), dict) else None,
        'quantity_sold': json_data.get('quantity_sold', {}).get('value') if isinstance(json_data.get('quantity_sold'), dict) else None,
        'brand_name': json_data.get('brand', {}).get('name') if isinstance(json_data.get('brand'), dict) else None
    }

def crawl_product(pid, session):
    """Crawl một sản phẩm"""
    try:
        url = f'https://tiki.vn/api/v2/products/{pid}'
        params = {
            'platform': 'web',
            'spid': pid,
            'version': 3
        }

        response = session.get(url, headers=headers, params=params, timeout=15)

        if response.status_code == 200:
            content_type = response.headers.get('Content-Type', '')

            if 'application/json' in content_type:
                json_data = response.json()
                return {'status': 'success', 'data': parser_product(json_data), 'id': pid}
            else:
                return {'status': 'error', 'reason': 'Not JSON response', 'id': pid}

        elif response.status_code == 404:
            return {'status': 'error', 'reason': '404 Not Found', 'id': pid}
        elif response.status_code == 403:
            return {'status': 'error', 'reason': '403 Forbidden', 'id': pid}
        else:
            return {'status': 'error', 'reason': f'HTTP {response.status_code}', 'id': pid}

    except requests.exceptions.Timeout:
        return {'status': 'error', 'reason': 'Timeout', 'id': pid}
    except requests.exceptions.JSONDecodeError:
        return {'status': 'error', 'reason': 'JSON decode error', 'id': pid}
    except Exception as e:
        return {'status': 'error', 'reason': str(e)[:100], 'id': pid}

def crawl_batch(p_ids, max_workers=10, delay_range=(0.1, 0.3)):
    """Crawl nhiều sản phẩm song song"""
    session = create_session()
    results = []
    failed_ids = []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit tất cả tasks
        future_to_pid = {
            executor.submit(crawl_product, pid, session): pid
            for pid in p_ids
        }

        # Progress bar
        with tqdm(total=len(p_ids), desc="Crawling") as pbar:
            for future in as_completed(future_to_pid):
                result = future.result()

                if result['status'] == 'success':
                    results.append(result['data'])
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})
                else:
                    failed_ids.append({'id': result['id'], 'reason': result['reason']})
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})

                pbar.update(1)

                # Delay nhỏ giữa các requests
                time.sleep(random.uniform(*delay_range))

    session.close()
    return results, failed_ids

# Main execution
if __name__ == "__main__":
    print("Đang đọc file product IDs...")
    df_id = pd.read_csv('/content/drive/MyDrive/Tiki_crawled_data/BẾP/BEP_id_ncds.csv')
    p_ids = df_id.id.to_list()
    print(f"Tổng số sản phẩm: {len(p_ids)}")

    # Crawl với 10 workers song song
    print("\nBắt đầu crawl...")
    start_time = time.time()

    results, failed_ids = crawl_batch(
        p_ids,
        max_workers=10,  # Số luồng song song (tăng lên 15-20 nếu muốn nhanh hơn)
        delay_range=(0.1, 0.3)  # Delay ngắn giữa các requests
    )

    elapsed_time = time.time() - start_time

    # Lưu kết quả
    if results:
        df_product = pd.DataFrame(results)
        df_product.to_csv('/content/drive/MyDrive/Tiki_crawled_data/BẾP/BEP_data_ncds.csv', index=False)
        print(f'\n✓ Đã lưu {len(results)} sản phẩm vào crawled_data_ncds.csv')

    if failed_ids:
        df_failed = pd.DataFrame(failed_ids)
        df_failed.to_csv('/content/drive/MyDrive/Tiki_crawled_data/BẾP/BEP_failed_ids_ncds.csv', index=False)
        print(f'✗ Đã lưu {len(failed_ids)} ID thất bại vào failed_ids_ncds.csv')

    # Thống kê
    print(f'\n{"="*60}')
    print(f'Tổng thời gian: {elapsed_time:.2f}s ({elapsed_time/60:.2f} phút)')
    print(f'Tốc độ trung bình: {len(p_ids)/elapsed_time:.2f} sản phẩm/giây')
    print(f'Thành công: {len(results)} ({len(results)/len(p_ids)*100:.1f}%)')
    print(f'Thất bại: {len(failed_ids)} ({len(failed_ids)/len(p_ids)*100:.1f}%)')
    print(f'{"="*60}')
# Out:
# Đang đọc file product IDs...
# Tổng số sản phẩm: 436
#
# Bắt đầu crawl...
# Crawling: 100%|██████████| 436/436 [01:29<00:00,  4.87it/s, ✓=211, ✗=225]
# ✓ Đã lưu 211 sản phẩm vào crawled_data_ncds.csv
# ✗ Đã lưu 225 ID thất bại vào failed_ids_ncds.csv
#
# ============================================================
# Tổng thời gian: 89.61s (1.49 phút)
# Tốc độ trung bình: 4.87 sản phẩm/giây
# Thành công: 211 (48.4%)
# Thất bại: 225 (51.6%)
# ============================================================

# %% [markdown]
# MÁY GIẶT

# %%
import requests
import time
import random
import pandas as pd

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/search?q=m%C3%A1y%20gi%E1%BA%B7t',
    'x-guest-token': 'io5g4hskF971zqMNtRm30QcIlV2vLuJf',
    'Connection': 'keep-alive',
    'TE': 'chunked',
}

params = {
    'limit': '40',
    'include': 'advertisement',
    'aggregations': '2',
    'trackity_id': 'd775c484-83cc-d67a-db5e-8f1e70299c40',
    'q': 'máy giặt',
    '_v': 'reduce_ads_092025',
}

product_id = []
for i in range(1, 11):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)
    if response.status_code == 200:
        print('request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
    time.sleep(random.randrange(3, 10))

df = pd.DataFrame(product_id)
df.to_csv('/content/drive/MyDrive/Tiki_crawled_data/MÁY GIẶT/MAYGIAT_id_ncds.csv', index=False)
# Out:
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!

# %%
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import time
import random

# Cấu hình session với connection pooling và retry
def create_session():
    session = requests.Session()
    retry_strategy = Retry(
        total=3,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504],
    )
    adapter = HTTPAdapter(
        max_retries=retry_strategy,
        pool_connections=50,
        pool_maxsize=50
    )
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    return session

# Headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/',
    'Connection': 'keep-alive',
}

def parser_product(json_data):
    """Parse JSON response thành dictionary"""
    return {
        'id': json_data.get('id'),
        'name': json_data.get('name'),
        'short_description': json_data.get('short_description'),
        'price': json_data.get('price'),
        'discount': json_data.get('discount'),
        'discount_rate': json_data.get('discount_rate'),
        'review_count': json_data.get('review_count'),
        'day_ago_created': json_data.get('day_ago_created', {}) if isinstance(json_data.get('day_ago_created'), dict) else None,
        'quantity_sold': json_data.get('quantity_sold', {}).get('value') if isinstance(json_data.get('quantity_sold'), dict) else None,
        'brand_name': json_data.get('brand', {}).get('name') if isinstance(json_data.get('brand'), dict) else None
    }

def crawl_product(pid, session):
    """Crawl một sản phẩm"""
    try:
        url = f'https://tiki.vn/api/v2/products/{pid}'
        params = {
            'platform': 'web',
            'spid': pid,
            'version': 3
        }

        response = session.get(url, headers=headers, params=params, timeout=15)

        if response.status_code == 200:
            content_type = response.headers.get('Content-Type', '')

            if 'application/json' in content_type:
                json_data = response.json()
                return {'status': 'success', 'data': parser_product(json_data), 'id': pid}
            else:
                return {'status': 'error', 'reason': 'Not JSON response', 'id': pid}

        elif response.status_code == 404:
            return {'status': 'error', 'reason': '404 Not Found', 'id': pid}
        elif response.status_code == 403:
            return {'status': 'error', 'reason': '403 Forbidden', 'id': pid}
        else:
            return {'status': 'error', 'reason': f'HTTP {response.status_code}', 'id': pid}

    except requests.exceptions.Timeout:
        return {'status': 'error', 'reason': 'Timeout', 'id': pid}
    except requests.exceptions.JSONDecodeError:
        return {'status': 'error', 'reason': 'JSON decode error', 'id': pid}
    except Exception as e:
        return {'status': 'error', 'reason': str(e)[:100], 'id': pid}

def crawl_batch(p_ids, max_workers=10, delay_range=(0.1, 0.3)):
    """Crawl nhiều sản phẩm song song"""
    session = create_session()
    results = []
    failed_ids = []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit tất cả tasks
        future_to_pid = {
            executor.submit(crawl_product, pid, session): pid
            for pid in p_ids
        }

        # Progress bar
        with tqdm(total=len(p_ids), desc="Crawling") as pbar:
            for future in as_completed(future_to_pid):
                result = future.result()

                if result['status'] == 'success':
                    results.append(result['data'])
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})
                else:
                    failed_ids.append({'id': result['id'], 'reason': result['reason']})
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})

                pbar.update(1)

                # Delay nhỏ giữa các requests
                time.sleep(random.uniform(*delay_range))

    session.close()
    return results, failed_ids

# Main execution
if __name__ == "__main__":
    print("Đang đọc file product IDs...")
    df_id = pd.read_csv('/content/drive/MyDrive/Tiki_crawled_data/MÁY GIẶT/MAYGIAT_id_ncds.csv')
    p_ids = df_id.id.to_list()
    print(f"Tổng số sản phẩm: {len(p_ids)}")

    # Crawl với 10 workers song song
    print("\nBắt đầu crawl...")
    start_time = time.time()

    results, failed_ids = crawl_batch(
        p_ids,
        max_workers=10,  # Số luồng song song (tăng lên 15-20 nếu muốn nhanh hơn)
        delay_range=(0.1, 0.3)  # Delay ngắn giữa các requests
    )

    elapsed_time = time.time() - start_time

    # Lưu kết quả
    if results:
        df_product = pd.DataFrame(results)
        df_product.to_csv('/content/drive/MyDrive/Tiki_crawled_data/MÁY GIẶT/MAYGIAT_data_ncds.csv', index=False)
        print(f'\n✓ Đã lưu {len(results)} sản phẩm vào crawled_data_ncds.csv')

    if failed_ids:
        df_failed = pd.DataFrame(failed_ids)
        df_failed.to_csv('/content/drive/MyDrive/Tiki_crawled_data/MÁY GIẶT/MAYGIAT_failed_ids_ncds.csv', index=False)
        print(f'✗ Đã lưu {len(failed_ids)} ID thất bại vào failed_ids_ncds.csv')

    # Thống kê
    print(f'\n{"="*60}')
    print(f'Tổng thời gian: {elapsed_time:.2f}s ({elapsed_time/60:.2f} phút)')
    print(f'Tốc độ trung bình: {len(p_ids)/elapsed_time:.2f} sản phẩm/giây')
    print(f'Thành công: {len(results)} ({len(results)/len(p_ids)*100:.1f}%)')
    print(f'Thất bại: {len(failed_ids)} ({len(failed_ids)/len(p_ids)*100:.1f}%)')
    print(f'{"="*60}')
# Out:
# Đang đọc file product IDs...
# Tổng số sản phẩm: 436
#
# Bắt đầu crawl...
# Crawling: 100%|██████████| 436/436 [01:28<00:00,  4.91it/s, ✓=206, ✗=230]
# ✓ Đã lưu 206 sản phẩm vào crawled_data_ncds.csv
# ✗ Đã lưu 230 ID thất bại vào failed_ids_ncds.csv
#
# ============================================================
# Tổng thời gian: 88.91s (1.48 phút)
# Tốc độ trung bình: 4.90 sản phẩm/giây
# Thành công: 206 (47.2%)
# Thất bại: 230 (52.8%)
# ============================================================

# %% [markdown]
# ẤM SIÊU TỐC

# %%
import requests
import time
import random
import pandas as pd

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/search?q=%E1%BA%A5m%20si%C3%AAu%20t%E1%BB%91c',
    'x-guest-token': 'io5g4hskF971zqMNtRm30QcIlV2vLuJf',
    'Connection': 'keep-alive',
    'TE': 'chunked',
}

params = {
    'limit': '40',
    'include': 'advertisement',
    'aggregations': '2',
    'trackity_id': 'd775c484-83cc-d67a-db5e-8f1e70299c40',
    'q': 'ấm siêu tốc',
    '_v': 'reduce_ads_092025',
}

product_id = []
for i in range(1, 11):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)
    if response.status_code == 200:
        print('request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
    time.sleep(random.randrange(3, 10))

df = pd.DataFrame(product_id)
df.to_csv('/content/drive/MyDrive/Tiki_crawled_data/ẤM SIÊU TỐC/AMSIEUTOC_id_ncds.csv', index=False)
# Out:
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!

# %%
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import time
import random

# Cấu hình session với connection pooling và retry
def create_session():
    session = requests.Session()
    retry_strategy = Retry(
        total=3,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504],
    )
    adapter = HTTPAdapter(
        max_retries=retry_strategy,
        pool_connections=50,
        pool_maxsize=50
    )
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    return session

# Headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/',
    'Connection': 'keep-alive',
}

def parser_product(json_data):
    """Parse JSON response thành dictionary"""
    return {
        'id': json_data.get('id'),
        'name': json_data.get('name'),
        'short_description': json_data.get('short_description'),
        'price': json_data.get('price'),
        'discount': json_data.get('discount'),
        'discount_rate': json_data.get('discount_rate'),
        'review_count': json_data.get('review_count'),
        'day_ago_created': json_data.get('day_ago_created', {}) if isinstance(json_data.get('day_ago_created'), dict) else None,
        'quantity_sold': json_data.get('quantity_sold', {}).get('value') if isinstance(json_data.get('quantity_sold'), dict) else None,
        'brand_name': json_data.get('brand', {}).get('name') if isinstance(json_data.get('brand'), dict) else None
    }

def crawl_product(pid, session):
    """Crawl một sản phẩm"""
    try:
        url = f'https://tiki.vn/api/v2/products/{pid}'
        params = {
            'platform': 'web',
            'spid': pid,
            'version': 3
        }

        response = session.get(url, headers=headers, params=params, timeout=15)

        if response.status_code == 200:
            content_type = response.headers.get('Content-Type', '')

            if 'application/json' in content_type:
                json_data = response.json()
                return {'status': 'success', 'data': parser_product(json_data), 'id': pid}
            else:
                return {'status': 'error', 'reason': 'Not JSON response', 'id': pid}

        elif response.status_code == 404:
            return {'status': 'error', 'reason': '404 Not Found', 'id': pid}
        elif response.status_code == 403:
            return {'status': 'error', 'reason': '403 Forbidden', 'id': pid}
        else:
            return {'status': 'error', 'reason': f'HTTP {response.status_code}', 'id': pid}

    except requests.exceptions.Timeout:
        return {'status': 'error', 'reason': 'Timeout', 'id': pid}
    except requests.exceptions.JSONDecodeError:
        return {'status': 'error', 'reason': 'JSON decode error', 'id': pid}
    except Exception as e:
        return {'status': 'error', 'reason': str(e)[:100], 'id': pid}

def crawl_batch(p_ids, max_workers=10, delay_range=(0.1, 0.3)):
    """Crawl nhiều sản phẩm song song"""
    session = create_session()
    results = []
    failed_ids = []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit tất cả tasks
        future_to_pid = {
            executor.submit(crawl_product, pid, session): pid
            for pid in p_ids
        }

        # Progress bar
        with tqdm(total=len(p_ids), desc="Crawling") as pbar:
            for future in as_completed(future_to_pid):
                result = future.result()

                if result['status'] == 'success':
                    results.append(result['data'])
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})
                else:
                    failed_ids.append({'id': result['id'], 'reason': result['reason']})
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})

                pbar.update(1)

                # Delay nhỏ giữa các requests
                time.sleep(random.uniform(*delay_range))

    session.close()
    return results, failed_ids

# Main execution
if __name__ == "__main__":
    print("Đang đọc file product IDs...")
    df_id = pd.read_csv('/content/drive/MyDrive/Tiki_crawled_data/ẤM SIÊU TỐC/AMSIEUTOC_id_ncds.csv')
    p_ids = df_id.id.to_list()
    print(f"Tổng số sản phẩm: {len(p_ids)}")

    # Crawl với 10 workers song song
    print("\nBắt đầu crawl...")
    start_time = time.time()

    results, failed_ids = crawl_batch(
        p_ids,
        max_workers=10,  # Số luồng song song (tăng lên 15-20 nếu muốn nhanh hơn)
        delay_range=(0.1, 0.3)  # Delay ngắn giữa các requests
    )

    elapsed_time = time.time() - start_time

    # Lưu kết quả
    if results:
        df_product = pd.DataFrame(results)
        df_product.to_csv('/content/drive/MyDrive/Tiki_crawled_data/ẤM SIÊU TỐC/AMSIEUTOC_data_ncds.csv', index=False)
        print(f'\n✓ Đã lưu {len(results)} sản phẩm vào crawled_data_ncds.csv')

    if failed_ids:
        df_failed = pd.DataFrame(failed_ids)
        df_failed.to_csv('/content/drive/MyDrive/Tiki_crawled_data/ẤM SIÊU TỐC/AMSIEUTOC_failed_ids_ncds.csv', index=False)
        print(f'✗ Đã lưu {len(failed_ids)} ID thất bại vào failed_ids_ncds.csv')

    # Thống kê
    print(f'\n{"="*60}')
    print(f'Tổng thời gian: {elapsed_time:.2f}s ({elapsed_time/60:.2f} phút)')
    print(f'Tốc độ trung bình: {len(p_ids)/elapsed_time:.2f} sản phẩm/giây')
    print(f'Thành công: {len(results)} ({len(results)/len(p_ids)*100:.1f}%)')
    print(f'Thất bại: {len(failed_ids)} ({len(failed_ids)/len(p_ids)*100:.1f}%)')
    print(f'{"="*60}')
# Out:
# Đang đọc file product IDs...
# Tổng số sản phẩm: 436
#
# Bắt đầu crawl...
# Crawling: 100%|██████████| 436/436 [01:29<00:00,  4.90it/s, ✓=205, ✗=231]
# ✓ Đã lưu 205 sản phẩm vào crawled_data_ncds.csv
# ✗ Đã lưu 231 ID thất bại vào failed_ids_ncds.csv
#
# ============================================================
# Tổng thời gian: 89.08s (1.48 phút)
# Tốc độ trung bình: 4.89 sản phẩm/giây
# Thành công: 205 (47.0%)
# Thất bại: 231 (53.0%)
# ============================================================

# %% [markdown]
# QUẠT

# %%
import requests
import time
import random
import pandas as pd

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/search?q=qu%E1%BA%A1t',
    'x-guest-token': 'io5g4hskF971zqMNtRm30QcIlV2vLuJf',
    'Connection': 'keep-alive',
    'TE': 'chunked',
}

params = {
    'limit': '40',
    'include': 'advertisement',
    'aggregations': '2',
    'trackity_id': 'd775c484-83cc-d67a-db5e-8f1e70299c40',
    'q': 'quạt',
    '_v': 'reduce_ads_092025',
}

product_id = []
for i in range(1, 11):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)
    if response.status_code == 200:
        print('request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
    time.sleep(random.randrange(3, 10))

df = pd.DataFrame(product_id)
df.to_csv('/content/drive/MyDrive/Tiki_crawled_data/QUẠT/QUAT_id_ncds.csv', index=False)
# Out:
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!

# %%
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import time
import random

# Cấu hình session với connection pooling và retry
def create_session():
    session = requests.Session()
    retry_strategy = Retry(
        total=3,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504],
    )
    adapter = HTTPAdapter(
        max_retries=retry_strategy,
        pool_connections=50,
        pool_maxsize=50
    )
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    return session

# Headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/',
    'Connection': 'keep-alive',
}

def parser_product(json_data):
    """Parse JSON response thành dictionary"""
    return {
        'id': json_data.get('id'),
        'name': json_data.get('name'),
        'short_description': json_data.get('short_description'),
        'price': json_data.get('price'),
        'discount': json_data.get('discount'),
        'discount_rate': json_data.get('discount_rate'),
        'review_count': json_data.get('review_count'),
        'day_ago_created': json_data.get('day_ago_created', {}) if isinstance(json_data.get('day_ago_created'), dict) else None,
        'quantity_sold': json_data.get('quantity_sold', {}).get('value') if isinstance(json_data.get('quantity_sold'), dict) else None,
        'brand_name': json_data.get('brand', {}).get('name') if isinstance(json_data.get('brand'), dict) else None
    }

def crawl_product(pid, session):
    """Crawl một sản phẩm"""
    try:
        url = f'https://tiki.vn/api/v2/products/{pid}'
        params = {
            'platform': 'web',
            'spid': 34240151,
            'version': 3
        }

        response = session.get(url, headers=headers, params=params, timeout=15)

        if response.status_code == 200:
            content_type = response.headers.get('Content-Type', '')

            if 'application/json' in content_type:
                json_data = response.json()
                return {'status': 'success', 'data': parser_product(json_data), 'id': pid}
            else:
                return {'status': 'error', 'reason': 'Not JSON response', 'id': pid}

        elif response.status_code == 404:
            return {'status': 'error', 'reason': '404 Not Found', 'id': pid}
        elif response.status_code == 403:
            return {'status': 'error', 'reason': '403 Forbidden', 'id': pid}
        else:
            return {'status': 'error', 'reason': f'HTTP {response.status_code}', 'id': pid}

    except requests.exceptions.Timeout:
        return {'status': 'error', 'reason': 'Timeout', 'id': pid}
    except requests.exceptions.JSONDecodeError:
        return {'status': 'error', 'reason': 'JSON decode error', 'id': pid}
    except Exception as e:
        return {'status': 'error', 'reason': str(e)[:100], 'id': pid}

def crawl_batch(p_ids, max_workers=10, delay_range=(0.1, 0.3)):
    """Crawl nhiều sản phẩm song song"""
    session = create_session()
    results = []
    failed_ids = []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit tất cả tasks
        future_to_pid = {
            executor.submit(crawl_product, pid, session): pid
            for pid in p_ids
        }

        # Progress bar
        with tqdm(total=len(p_ids), desc="Crawling") as pbar:
            for future in as_completed(future_to_pid):
                result = future.result()

                if result['status'] == 'success':
                    results.append(result['data'])
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})
                else:
                    failed_ids.append({'id': result['id'], 'reason': result['reason']})
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})

                pbar.update(1)

                # Delay nhỏ giữa các requests
                time.sleep(random.uniform(*delay_range))

    session.close()
    return results, failed_ids

# Main execution
if __name__ == "__main__":
    print("Đang đọc file product IDs...")
    df_id = pd.read_csv('/content/drive/MyDrive/Tiki_crawled_data/QUẠT/QUAT_id_ncds.csv')
    p_ids = df_id.id.to_list()
    print(f"Tổng số sản phẩm: {len(p_ids)}")

    # Crawl với 10 workers song song
    print("\nBắt đầu crawl...")
    start_time = time.time()

    results, failed_ids = crawl_batch(
        p_ids,
        max_workers=10,  # Số luồng song song (tăng lên 15-20 nếu muốn nhanh hơn)
        delay_range=(0.1, 0.3)  # Delay ngắn giữa các requests
    )

    elapsed_time = time.time() - start_time

    # Lưu kết quả
    if results:
        df_product = pd.DataFrame(results)
        df_product.to_csv('/content/drive/MyDrive/Tiki_crawled_data/QUẠT/QUAT_data_ncds.csv', index=False)
        print(f'\n✓ Đã lưu {len(results)} sản phẩm vào crawled_data_ncds.csv')

    if failed_ids:
        df_failed = pd.DataFrame(failed_ids)
        df_failed.to_csv('/content/drive/MyDrive/Tiki_crawled_data/QUẠT/QUAT_failed_ids_ncds.csv', index=False)
        print(f'✗ Đã lưu {len(failed_ids)} ID thất bại vào failed_ids_ncds.csv')

    # Thống kê
    print(f'\n{"="*60}')
    print(f'Tổng thời gian: {elapsed_time:.2f}s ({elapsed_time/60:.2f} phút)')
    print(f'Tốc độ trung bình: {len(p_ids)/elapsed_time:.2f} sản phẩm/giây')
    print(f'Thành công: {len(results)} ({len(results)/len(p_ids)*100:.1f}%)')
    print(f'Thất bại: {len(failed_ids)} ({len(failed_ids)/len(p_ids)*100:.1f}%)')
    print(f'{"="*60}')
# Out:
# Đang đọc file product IDs...
# Tổng số sản phẩm: 436
#
# Bắt đầu crawl...
# Crawling: 100%|██████████| 436/436 [01:29<00:00,  4.86it/s, ✓=216, ✗=220]
# ✓ Đã lưu 216 sản phẩm vào crawled_data_ncds.csv
# ✗ Đã lưu 220 ID thất bại vào failed_ids_ncds.csv
#
# ============================================================
# Tổng thời gian: 89.94s (1.50 phút)
# Tốc độ trung bình: 4.85 sản phẩm/giây
# Thành công: 216 (49.5%)
# Thất bại: 220 (50.5%)
# ============================================================

# %% [markdown]
# TIVI

# %%
import requests
import time
import random
import pandas as pd

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/search?q=tivi',
    'x-guest-token': 'io5g4hskF971zqMNtRm30QcIlV2vLuJf',
    'Connection': 'keep-alive',
    'TE': 'chunked',
}

params = {
    'limit': '40',
    'include': 'advertisement',
    'aggregations': '2',
    'trackity_id': 'd775c484-83cc-d67a-db5e-8f1e70299c40',
    'q': 'tivi',
    '_v': 'reduce_ads_092025',
}

product_id = []
for i in range(1, 11):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)
    if response.status_code == 200:
        print('request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
    time.sleep(random.randrange(3, 10))

df = pd.DataFrame(product_id)
df.to_csv('/content/drive/MyDrive/Tiki_crawled_data/TIVI/TIVI_id_ncds.csv', index=False)
# Out:
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!

# %%
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import time
import random

# Cấu hình session với connection pooling và retry
def create_session():
    session = requests.Session()
    retry_strategy = Retry(
        total=3,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504],
    )
    adapter = HTTPAdapter(
        max_retries=retry_strategy,
        pool_connections=50,
        pool_maxsize=50
    )
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    return session

# Headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/',
    'Connection': 'keep-alive',
}

def parser_product(json_data):
    """Parse JSON response thành dictionary"""
    return {
        'id': json_data.get('id'),
        'name': json_data.get('name'),
        'short_description': json_data.get('short_description'),
        'price': json_data.get('price'),
        'discount': json_data.get('discount'),
        'discount_rate': json_data.get('discount_rate'),
        'review_count': json_data.get('review_count'),
        'day_ago_created': json_data.get('day_ago_created', {}) if isinstance(json_data.get('day_ago_created'), dict) else None,
        'quantity_sold': json_data.get('quantity_sold', {}).get('value') if isinstance(json_data.get('quantity_sold'), dict) else None,
        'brand_name': json_data.get('brand', {}).get('name') if isinstance(json_data.get('brand'), dict) else None
    }

def crawl_product(pid, session):
    """Crawl một sản phẩm"""
    try:
        url = f'https://tiki.vn/api/v2/products/{pid}'
        params = {
            'platform': 'web',
            'spid': 214962211,
            'version': 3
        }

        response = session.get(url, headers=headers, params=params, timeout=15)

        if response.status_code == 200:
            content_type = response.headers.get('Content-Type', '')

            if 'application/json' in content_type:
                json_data = response.json()
                return {'status': 'success', 'data': parser_product(json_data), 'id': pid}
            else:
                return {'status': 'error', 'reason': 'Not JSON response', 'id': pid}

        elif response.status_code == 404:
            return {'status': 'error', 'reason': '404 Not Found', 'id': pid}
        elif response.status_code == 403:
            return {'status': 'error', 'reason': '403 Forbidden', 'id': pid}
        else:
            return {'status': 'error', 'reason': f'HTTP {response.status_code}', 'id': pid}

    except requests.exceptions.Timeout:
        return {'status': 'error', 'reason': 'Timeout', 'id': pid}
    except requests.exceptions.JSONDecodeError:
        return {'status': 'error', 'reason': 'JSON decode error', 'id': pid}
    except Exception as e:
        return {'status': 'error', 'reason': str(e)[:100], 'id': pid}

def crawl_batch(p_ids, max_workers=10, delay_range=(0.1, 0.3)):
    """Crawl nhiều sản phẩm song song"""
    session = create_session()
    results = []
    failed_ids = []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit tất cả tasks
        future_to_pid = {
            executor.submit(crawl_product, pid, session): pid
            for pid in p_ids
        }

        # Progress bar
        with tqdm(total=len(p_ids), desc="Crawling") as pbar:
            for future in as_completed(future_to_pid):
                result = future.result()

                if result['status'] == 'success':
                    results.append(result['data'])
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})
                else:
                    failed_ids.append({'id': result['id'], 'reason': result['reason']})
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})

                pbar.update(1)

                # Delay nhỏ giữa các requests
                time.sleep(random.uniform(*delay_range))

    session.close()
    return results, failed_ids

# Main execution
if __name__ == "__main__":
    print("Đang đọc file product IDs...")
    df_id = pd.read_csv('/content/drive/MyDrive/Tiki_crawled_data/TIVI/TIVI_id_ncds.csv')
    p_ids = df_id.id.to_list()
    print(f"Tổng số sản phẩm: {len(p_ids)}")

    # Crawl với 10 workers song song
    print("\nBắt đầu crawl...")
    start_time = time.time()

    results, failed_ids = crawl_batch(
        p_ids,
        max_workers=10,  # Số luồng song song (tăng lên 15-20 nếu muốn nhanh hơn)
        delay_range=(0.1, 0.3)  # Delay ngắn giữa các requests
    )

    elapsed_time = time.time() - start_time

    # Lưu kết quả
    if results:
        df_product = pd.DataFrame(results)
        df_product.to_csv('/content/drive/MyDrive/Tiki_crawled_data/TIVI/TIVI_data_ncds.csv', index=False)
        print(f'\n✓ Đã lưu {len(results)} sản phẩm vào crawled_data_ncds.csv')

    if failed_ids:
        df_failed = pd.DataFrame(failed_ids)
        df_failed.to_csv('/content/drive/MyDrive/Tiki_crawled_data/TIVI/TIVI_failed_ids_ncds.csv', index=False)
        print(f'✗ Đã lưu {len(failed_ids)} ID thất bại vào failed_ids_ncds.csv')

    # Thống kê
    print(f'\n{"="*60}')
    print(f'Tổng thời gian: {elapsed_time:.2f}s ({elapsed_time/60:.2f} phút)')
    print(f'Tốc độ trung bình: {len(p_ids)/elapsed_time:.2f} sản phẩm/giây')
    print(f'Thành công: {len(results)} ({len(results)/len(p_ids)*100:.1f}%)')
    print(f'Thất bại: {len(failed_ids)} ({len(failed_ids)/len(p_ids)*100:.1f}%)')
    print(f'{"="*60}')
# Out:
# Đang đọc file product IDs...
# Tổng số sản phẩm: 400
#
# Bắt đầu crawl...
# Crawling: 100%|██████████| 400/400 [01:22<00:00,  4.85it/s, ✓=215, ✗=185]
# ✓ Đã lưu 215 sản phẩm vào crawled_data_ncds.csv
# ✗ Đã lưu 185 ID thất bại vào failed_ids_ncds.csv
#
# ============================================================
# Tổng thời gian: 82.59s (1.38 phút)
# Tốc độ trung bình: 4.84 sản phẩm/giây
# Thành công: 215 (53.8%)
# Thất bại: 185 (46.2%)
# ============================================================

# %% [markdown]
# LÒ NƯỚNG

# %%
import requests
import time
import random
import pandas as pd

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/search?q=l%C3%B2%20n%C6%B0%E1%BB%9Bng',
    'x-guest-token': 'io5g4hskF971zqMNtRm30QcIlV2vLuJf',
    'Connection': 'keep-alive',
    'TE': 'chunked',
}

params = {
    'limit': '40',
    'include': 'advertisement',
    'aggregations': '2',
    'trackity_id': 'd775c484-83cc-d67a-db5e-8f1e70299c40',
    'q': 'lò nướng',
    '_v': 'reduce_ads_092025',
}

product_id = []
for i in range(1, 11):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)
    if response.status_code == 200:
        print('request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
    time.sleep(random.randrange(3, 10))

df = pd.DataFrame(product_id)
df.to_csv('/content/drive/MyDrive/Tiki_crawled_data/LÒ NƯỚNG/LONUONG_id_ncds.csv', index=False)
# Out:
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!

# %%
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import time
import random

# Cấu hình session với connection pooling và retry
def create_session():
    session = requests.Session()
    retry_strategy = Retry(
        total=3,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504],
    )
    adapter = HTTPAdapter(
        max_retries=retry_strategy,
        pool_connections=50,
        pool_maxsize=50
    )
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    return session

# Headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/',
    'Connection': 'keep-alive',
}

def parser_product(json_data):
    """Parse JSON response thành dictionary"""
    return {
        'id': json_data.get('id'),
        'name': json_data.get('name'),
        'short_description': json_data.get('short_description'),
        'price': json_data.get('price'),
        'discount': json_data.get('discount'),
        'discount_rate': json_data.get('discount_rate'),
        'review_count': json_data.get('review_count'),
        'day_ago_created': json_data.get('day_ago_created', {}) if isinstance(json_data.get('day_ago_created'), dict) else None,
        'quantity_sold': json_data.get('quantity_sold', {}).get('value') if isinstance(json_data.get('quantity_sold'), dict) else None,
        'brand_name': json_data.get('brand', {}).get('name') if isinstance(json_data.get('brand'), dict) else None
    }

def crawl_product(pid, session):
    """Crawl một sản phẩm"""
    try:
        url = f'https://tiki.vn/api/v2/products/{pid}'
        params = {
            'platform': 'web',
            'spid': 1941997,
            'version': 3
        }

        response = session.get(url, headers=headers, params=params, timeout=15)

        if response.status_code == 200:
            content_type = response.headers.get('Content-Type', '')

            if 'application/json' in content_type:
                json_data = response.json()
                return {'status': 'success', 'data': parser_product(json_data), 'id': pid}
            else:
                return {'status': 'error', 'reason': 'Not JSON response', 'id': pid}

        elif response.status_code == 404:
            return {'status': 'error', 'reason': '404 Not Found', 'id': pid}
        elif response.status_code == 403:
            return {'status': 'error', 'reason': '403 Forbidden', 'id': pid}
        else:
            return {'status': 'error', 'reason': f'HTTP {response.status_code}', 'id': pid}

    except requests.exceptions.Timeout:
        return {'status': 'error', 'reason': 'Timeout', 'id': pid}
    except requests.exceptions.JSONDecodeError:
        return {'status': 'error', 'reason': 'JSON decode error', 'id': pid}
    except Exception as e:
        return {'status': 'error', 'reason': str(e)[:100], 'id': pid}

def crawl_batch(p_ids, max_workers=10, delay_range=(0.1, 0.3)):
    """Crawl nhiều sản phẩm song song"""
    session = create_session()
    results = []
    failed_ids = []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit tất cả tasks
        future_to_pid = {
            executor.submit(crawl_product, pid, session): pid
            for pid in p_ids
        }

        # Progress bar
        with tqdm(total=len(p_ids), desc="Crawling") as pbar:
            for future in as_completed(future_to_pid):
                result = future.result()

                if result['status'] == 'success':
                    results.append(result['data'])
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})
                else:
                    failed_ids.append({'id': result['id'], 'reason': result['reason']})
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})

                pbar.update(1)

                # Delay nhỏ giữa các requests
                time.sleep(random.uniform(*delay_range))

    session.close()
    return results, failed_ids

# Main execution
if __name__ == "__main__":
    print("Đang đọc file product IDs...")
    df_id = pd.read_csv('/content/drive/MyDrive/Tiki_crawled_data/LÒ NƯỚNG/LONUONG_id_ncds.csv')
    p_ids = df_id.id.to_list()
    print(f"Tổng số sản phẩm: {len(p_ids)}")

    # Crawl với 10 workers song song
    print("\nBắt đầu crawl...")
    start_time = time.time()

    results, failed_ids = crawl_batch(
        p_ids,
        max_workers=10,  # Số luồng song song (tăng lên 15-20 nếu muốn nhanh hơn)
        delay_range=(0.1, 0.3)  # Delay ngắn giữa các requests
    )

    elapsed_time = time.time() - start_time

    # Lưu kết quả
    if results:
        df_product = pd.DataFrame(results)
        df_product.to_csv('/content/drive/MyDrive/Tiki_crawled_data/LÒ NƯỚNG/LONUONG_data_ncds.csv', index=False)
        print(f'\n✓ Đã lưu {len(results)} sản phẩm vào crawled_data_ncds.csv')

    if failed_ids:
        df_failed = pd.DataFrame(failed_ids)
        df_failed.to_csv('/content/drive/MyDrive/Tiki_crawled_data/LÒ NƯỚNG/LONUONG_failed_ids_ncds.csv', index=False)
        print(f'✗ Đã lưu {len(failed_ids)} ID thất bại vào failed_ids_ncds.csv')

    # Thống kê
    print(f'\n{"="*60}')
    print(f'Tổng thời gian: {elapsed_time:.2f}s ({elapsed_time/60:.2f} phút)')
    print(f'Tốc độ trung bình: {len(p_ids)/elapsed_time:.2f} sản phẩm/giây')
    print(f'Thành công: {len(results)} ({len(results)/len(p_ids)*100:.1f}%)')
    print(f'Thất bại: {len(failed_ids)} ({len(failed_ids)/len(p_ids)*100:.1f}%)')
    print(f'{"="*60}')
# Out:
# Đang đọc file product IDs...
# Tổng số sản phẩm: 404
#
# Bắt đầu crawl...
# Crawling: 100%|██████████| 404/404 [01:21<00:00,  4.96it/s, ✓=207, ✗=197]
# ✓ Đã lưu 207 sản phẩm vào crawled_data_ncds.csv
# ✗ Đã lưu 197 ID thất bại vào failed_ids_ncds.csv
#
# ============================================================
# Tổng thời gian: 81.46s (1.36 phút)
# Tốc độ trung bình: 4.96 sản phẩm/giây
# Thành công: 207 (51.2%)
# Thất bại: 197 (48.8%)
# ============================================================

# %% [markdown]
# MÁY HÚT BỤI

# %%
import requests
import time
import random
import pandas as pd

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/search?q=m%C3%A1y%20h%C3%BAt%20b%E1%BB%A5i',
    'x-guest-token': 'io5g4hskF971zqMNtRm30QcIlV2vLuJf',
    'Connection': 'keep-alive',
    'TE': 'chunked',
}

params = {
    'limit': '40',
    'include': 'advertisement',
    'aggregations': '2',
    'trackity_id': 'd775c484-83cc-d67a-db5e-8f1e70299c40',
    'q': 'máy hút bụi',
    '_v': 'reduce_ads_092025',
}

product_id = []
for i in range(1, 11):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)
    if response.status_code == 200:
        print('request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
    time.sleep(random.randrange(3, 10))

df = pd.DataFrame(product_id)
df.to_csv('/content/drive/MyDrive/Tiki_crawled_data/MÁY HÚT BỤI/MAYHUTBUI_id_ncds.csv', index=False)
# Out:
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!

# %%
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import time
import random

# Cấu hình session với connection pooling và retry
def create_session():
    session = requests.Session()
    retry_strategy = Retry(
        total=3,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504],
    )
    adapter = HTTPAdapter(
        max_retries=retry_strategy,
        pool_connections=50,
        pool_maxsize=50
    )
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    return session

# Headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/',
    'Connection': 'keep-alive',
}

def parser_product(json_data):
    """Parse JSON response thành dictionary"""
    return {
        'id': json_data.get('id'),
        'name': json_data.get('name'),
        'short_description': json_data.get('short_description'),
        'price': json_data.get('price'),
        'discount': json_data.get('discount'),
        'discount_rate': json_data.get('discount_rate'),
        'review_count': json_data.get('review_count'),
        'day_ago_created': json_data.get('day_ago_created', {}) if isinstance(json_data.get('day_ago_created'), dict) else None,
        'quantity_sold': json_data.get('quantity_sold', {}).get('value') if isinstance(json_data.get('quantity_sold'), dict) else None,
        'brand_name': json_data.get('brand', {}).get('name') if isinstance(json_data.get('brand'), dict) else None
    }

def crawl_product(pid, session):
    """Crawl một sản phẩm"""
    try:
        url = f'https://tiki.vn/api/v2/products/{pid}'
        params = {
            'platform': 'web',
            'spid': 66512833,
            'version': 3
        }

        response = session.get(url, headers=headers, params=params, timeout=15)

        if response.status_code == 200:
            content_type = response.headers.get('Content-Type', '')

            if 'application/json' in content_type:
                json_data = response.json()
                return {'status': 'success', 'data': parser_product(json_data), 'id': pid}
            else:
                return {'status': 'error', 'reason': 'Not JSON response', 'id': pid}

        elif response.status_code == 404:
            return {'status': 'error', 'reason': '404 Not Found', 'id': pid}
        elif response.status_code == 403:
            return {'status': 'error', 'reason': '403 Forbidden', 'id': pid}
        else:
            return {'status': 'error', 'reason': f'HTTP {response.status_code}', 'id': pid}

    except requests.exceptions.Timeout:
        return {'status': 'error', 'reason': 'Timeout', 'id': pid}
    except requests.exceptions.JSONDecodeError:
        return {'status': 'error', 'reason': 'JSON decode error', 'id': pid}
    except Exception as e:
        return {'status': 'error', 'reason': str(e)[:100], 'id': pid}

def crawl_batch(p_ids, max_workers=10, delay_range=(0.1, 0.3)):
    """Crawl nhiều sản phẩm song song"""
    session = create_session()
    results = []
    failed_ids = []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit tất cả tasks
        future_to_pid = {
            executor.submit(crawl_product, pid, session): pid
            for pid in p_ids
        }

        # Progress bar
        with tqdm(total=len(p_ids), desc="Crawling") as pbar:
            for future in as_completed(future_to_pid):
                result = future.result()

                if result['status'] == 'success':
                    results.append(result['data'])
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})
                else:
                    failed_ids.append({'id': result['id'], 'reason': result['reason']})
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})

                pbar.update(1)

                # Delay nhỏ giữa các requests
                time.sleep(random.uniform(*delay_range))

    session.close()
    return results, failed_ids

# Main execution
if __name__ == "__main__":
    print("Đang đọc file product IDs...")
    df_id = pd.read_csv('/content/drive/MyDrive/Tiki_crawled_data/MÁY HÚT BỤI/MAYHUTBUI_id_ncds.csv')
    p_ids = df_id.id.to_list()
    print(f"Tổng số sản phẩm: {len(p_ids)}")

    # Crawl với 10 workers song song
    print("\nBắt đầu crawl...")
    start_time = time.time()

    results, failed_ids = crawl_batch(
        p_ids,
        max_workers=10,  # Số luồng song song (tăng lên 15-20 nếu muốn nhanh hơn)
        delay_range=(0.1, 0.3)  # Delay ngắn giữa các requests
    )

    elapsed_time = time.time() - start_time

    # Lưu kết quả
    if results:
        df_product = pd.DataFrame(results)
        df_product.to_csv('/content/drive/MyDrive/Tiki_crawled_data/MÁY HÚT BỤI/MAYHUTBUI_data_ncds.csv', index=False)
        print(f'\n✓ Đã lưu {len(results)} sản phẩm vào crawled_data_ncds.csv')

    if failed_ids:
        df_failed = pd.DataFrame(failed_ids)
        df_failed.to_csv('/content/drive/MyDrive/Tiki_crawled_data/MÁY HÚT BỤI/MAYHUTBUI_failed_ids_ncds.csv', index=False)
        print(f'✗ Đã lưu {len(failed_ids)} ID thất bại vào failed_ids_ncds.csv')

    # Thống kê
    print(f'\n{"="*60}')
    print(f'Tổng thời gian: {elapsed_time:.2f}s ({elapsed_time/60:.2f} phút)')
    print(f'Tốc độ trung bình: {len(p_ids)/elapsed_time:.2f} sản phẩm/giây')
    print(f'Thành công: {len(results)} ({len(results)/len(p_ids)*100:.1f}%)')
    print(f'Thất bại: {len(failed_ids)} ({len(failed_ids)/len(p_ids)*100:.1f}%)')
    print(f'{"="*60}')
# Out:
# Đang đọc file product IDs...
# Tổng số sản phẩm: 434
#
# Bắt đầu crawl...
# Crawling: 100%|██████████| 434/434 [01:28<00:00,  4.92it/s, ✓=202, ✗=232]
# ✓ Đã lưu 202 sản phẩm vào crawled_data_ncds.csv
# ✗ Đã lưu 232 ID thất bại vào failed_ids_ncds.csv
#
# ============================================================
# Tổng thời gian: 88.18s (1.47 phút)
# Tốc độ trung bình: 4.92 sản phẩm/giây
# Thành công: 202 (46.5%)
# Thất bại: 232 (53.5%)
# ============================================================

# %% [markdown]
# BÀN ỦI

# %%
import requests
import time
import random
import pandas as pd

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/search?q=b%C3%A0n%20%E1%BB%A7i',
    'x-guest-token': 'io5g4hskF971zqMNtRm30QcIlV2vLuJf',
    'Connection': 'keep-alive',
    'TE': 'chunked',
}

params = {
    'limit': '40',
    'include': 'advertisement',
    'aggregations': '2',
    'trackity_id': 'd775c484-83cc-d67a-db5e-8f1e70299c40',
    'q': 'bàn ủi',
    '_v': 'reduce_ads_092025',
}

product_id = []
for i in range(1, 11):
    params['page'] = i
    response = requests.get('https://tiki.vn/api/v2/products', headers=headers, params=params)
    if response.status_code == 200:
        print('request success!!!')
        for record in response.json().get('data'):
            product_id.append({'id': record.get('id')})
    time.sleep(random.randrange(3, 10))

df = pd.DataFrame(product_id)
df.to_csv('/content/drive/MyDrive/Tiki_crawled_data/BÀN ỦI/BANUI_id_ncds.csv', index=False)
# Out:
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!
# request success!!!

# %%
import pandas as pd
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import time
import random

# Cấu hình session với connection pooling và retry
def create_session():
    session = requests.Session()
    retry_strategy = Retry(
        total=3,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504],
    )
    adapter = HTTPAdapter(
        max_retries=retry_strategy,
        pool_connections=50,
        pool_maxsize=50
    )
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    return session

# Headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.9',
    'Referer': 'https://tiki.vn/',
    'Connection': 'keep-alive',
}

def parser_product(json_data):
    """Parse JSON response thành dictionary"""
    return {
        'id': json_data.get('id'),
        'name': json_data.get('name'),
        'short_description': json_data.get('short_description'),
        'price': json_data.get('price'),
        'discount': json_data.get('discount'),
        'discount_rate': json_data.get('discount_rate'),
        'review_count': json_data.get('review_count'),
        'day_ago_created': json_data.get('day_ago_created', {}) if isinstance(json_data.get('day_ago_created'), dict) else None,
        'quantity_sold': json_data.get('quantity_sold', {}).get('value') if isinstance(json_data.get('quantity_sold'), dict) else None,
        'brand_name': json_data.get('brand', {}).get('name') if isinstance(json_data.get('brand'), dict) else None
    }

def crawl_product(pid, session):
    """Crawl một sản phẩm"""
    try:
        url = f'https://tiki.vn/api/v2/products/{pid}'
        params = {
            'platform': 'web',
            'spid': 92969,
            'version': 3
        }

        response = session.get(url, headers=headers, params=params, timeout=15)

        if response.status_code == 200:
            content_type = response.headers.get('Content-Type', '')

            if 'application/json' in content_type:
                json_data = response.json()
                return {'status': 'success', 'data': parser_product(json_data), 'id': pid}
            else:
                return {'status': 'error', 'reason': 'Not JSON response', 'id': pid}

        elif response.status_code == 404:
            return {'status': 'error', 'reason': '404 Not Found', 'id': pid}
        elif response.status_code == 403:
            return {'status': 'error', 'reason': '403 Forbidden', 'id': pid}
        else:
            return {'status': 'error', 'reason': f'HTTP {response.status_code}', 'id': pid}

    except requests.exceptions.Timeout:
        return {'status': 'error', 'reason': 'Timeout', 'id': pid}
    except requests.exceptions.JSONDecodeError:
        return {'status': 'error', 'reason': 'JSON decode error', 'id': pid}
    except Exception as e:
        return {'status': 'error', 'reason': str(e)[:100], 'id': pid}

def crawl_batch(p_ids, max_workers=10, delay_range=(0.1, 0.3)):
    """Crawl nhiều sản phẩm song song"""
    session = create_session()
    results = []
    failed_ids = []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit tất cả tasks
        future_to_pid = {
            executor.submit(crawl_product, pid, session): pid
            for pid in p_ids
        }

        # Progress bar
        with tqdm(total=len(p_ids), desc="Crawling") as pbar:
            for future in as_completed(future_to_pid):
                result = future.result()

                if result['status'] == 'success':
                    results.append(result['data'])
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})
                else:
                    failed_ids.append({'id': result['id'], 'reason': result['reason']})
                    pbar.set_postfix({'✓': len(results), '✗': len(failed_ids)})

                pbar.update(1)

                # Delay nhỏ giữa các requests
                time.sleep(random.uniform(*delay_range))

    session.close()
    return results, failed_ids

# Main execution
if __name__ == "__main__":
    print("Đang đọc file product IDs...")
    df_id = pd.read_csv('/content/drive/MyDrive/Tiki_crawled_data/BÀN ỦI/BANUI_id_ncds.csv')
    p_ids = df_id.id.to_list()
    print(f"Tổng số sản phẩm: {len(p_ids)}")

    # Crawl với 10 workers song song
    print("\nBắt đầu crawl...")
    start_time = time.time()

    results, failed_ids = crawl_batch(
        p_ids,
        max_workers=10,  # Số luồng song song (tăng lên 15-20 nếu muốn nhanh hơn)
        delay_range=(0.1, 0.3)  # Delay ngắn giữa các requests
    )

    elapsed_time = time.time() - start_time

    # Lưu kết quả
    if results:
        df_product = pd.DataFrame(results)
        df_product.to_csv('/content/drive/MyDrive/Tiki_crawled_data/BÀN ỦI/BANUI_data_ncds.csv', index=False)
        print(f'\n✓ Đã lưu {len(results)} sản phẩm vào crawled_data_ncds.csv')

    if failed_ids:
        df_failed = pd.DataFrame(failed_ids)
        df_failed.to_csv('/content/drive/MyDrive/Tiki_crawled_data/BÀN ỦI/BANUI_failed_ids_ncds.csv', index=False)
        print(f'✗ Đã lưu {len(failed_ids)} ID thất bại vào failed_ids_ncds.csv')

    # Thống kê
    print(f'\n{"="*60}')
    print(f'Tổng thời gian: {elapsed_time:.2f}s ({elapsed_time/60:.2f} phút)')
    print(f'Tốc độ trung bình: {len(p_ids)/elapsed_time:.2f} sản phẩm/giây')
    print(f'Thành công: {len(results)} ({len(results)/len(p_ids)*100:.1f}%)')
    print(f'Thất bại: {len(failed_ids)} ({len(failed_ids)/len(p_ids)*100:.1f}%)')
    print(f'{"="*60}')
# Out:
# Đang đọc file product IDs...
# Tổng số sản phẩm: 436
#
# Bắt đầu crawl...
# Crawling: 100%|██████████| 436/436 [01:29<00:00,  4.88it/s, ✓=207, ✗=229]
# ✓ Đã lưu 207 sản phẩm vào crawled_data_ncds.csv
# ✗ Đã lưu 229 ID thất bại vào failed_ids_ncds.csv
#
# ============================================================
# Tổng thời gian: 89.41s (1.49 phút)
# Tốc độ trung bình: 4.88 sản phẩm/giây
# Thành công: 207 (47.5%)
# Thất bại: 229 (52.5%)
# ============================================================
